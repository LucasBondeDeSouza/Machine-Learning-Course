# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import pickle

# %%
with open('risco_credito.pkl', 'rb') as f:
    x_risco_credito, y_risco_credito = pickle.load(f)

# %% [markdown]
# # Árvores de Decisão

# %%
from sklearn.tree import DecisionTreeClassifier

# %% [markdown]
# ### Treinamento do Algorítmo

# %%
arvore_risco_credito = DecisionTreeClassifier(criterion='entropy')
arvore_risco_credito.fit(x_risco_credito, y_risco_credito)
# Out:
# DecisionTreeClassifier(criterion='entropy')

# %% [markdown]
# ### Exibindo a Árvore de Decisão

# %%
from sklearn import tree
previsores = ['história', 'dívida', 'garantias', 'renda']
figura, eixos = plt.subplots(nrows=1, ncols=1, figsize=(10, 10))
tree.plot_tree(arvore_risco_credito, feature_names=previsores, class_names=arvore_risco_credito.classes_, filled=True)
# Out:
# [Text(0.5555555555555556, 0.9166666666666666, 'renda <= 1.5\nentropy = 1.531\nsamples = 14\nvalue = [6, 5, 3]\nclass = alto'),
#  Text(0.3333333333333333, 0.75, 'história <= 1.5\nentropy = 0.863\nsamples = 7\nvalue = [5, 0, 2]\nclass = alto'),
#  Text(0.4444444444444444, 0.8333333333333333, 'True  '),
#  Text(0.2222222222222222, 0.5833333333333334, 'renda <= 0.5\nentropy = 1.0\nsamples = 4\nvalue = [2, 0, 2]\nclass = alto'),
#  Text(0.1111111111111111, 0.4166666666666667, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = alto'),
#  Text(0.3333333333333333, 0.4166666666666667, 'história <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 0, 2]\nclass = moderado'),
#  Text(0.2222222222222222, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = moderado'),
#  Text(0.4444444444444444, 0.25, 'dívida <= 0.5\nentropy = 1.0\nsamples = 2\nvalue = [1, 0, 1]\nclass = alto'),
#  Text(0.3333333333333333, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [1, 0, 0]\nclass = alto'),
#  Text(0.5555555555555556, 0.08333333333333333, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = moderado'),
#  Text(0.4444444444444444, 0.5833333333333334, 'entropy = 0.0\nsamples = 3\nvalue = [3, 0, 0]\nclass = alto'),
#  Text(0.7777777777777778, 0.75, 'história <= 1.5\nentropy = 1.149\nsamples = 7\nvalue = [1, 5, 1]\nclass = baixo'),
#  Text(0.6666666666666667, 0.8333333333333333, '  False'),
#  Text(0.6666666666666666, 0.5833333333333334, 'história <= 0.5\nentropy = 0.65\nsamples = 6\nvalue = [1, 5, 0]\nclass = baixo'),
#  Text(0.5555555555555556, 0.4166666666666667, 'entropy = 0.0\nsamples = 3\nvalue = [0, 3, 0]\nclass = baixo'),
#  Text(0.7777777777777778, 0.4166666666666667, 'garantias <= 0.5\nentropy = 0.918\nsamples = 3\nvalue = [1, 2, 0]\nclass = baixo'),
#  Text(0.6666666666666666, 0.25, 'entropy = 0.0\nsamples = 1\nvalue = [0, 1, 0]\nclass = baixo'),
#  Text(0.8888888888888888, 0.25, 'entropy = 1.0\nsamples = 2\nvalue = [1, 1, 0]\nclass = alto'),
#  Text(0.8888888888888888, 0.5833333333333334, 'entropy = 0.0\nsamples = 1\nvalue = [0, 0, 1]\nclass = moderado')]

# %% [markdown]
# ### Previsões

# %%
# história boa (0), dívida alta (0), garantias nenhuma (1), renda > 35 (2)
# história ruim (2), dívida alta (0), garantias adequada (0), renda < 15 (0)

previsoes = arvore_risco_credito.predict([[0,0,1,2], [2,0,0,0], [0, 0, 0, 0], [2, 0, 1, 2]])
previsoes
# Out:
# array(['baixo', 'alto', 'alto', 'moderado'], dtype=object)
